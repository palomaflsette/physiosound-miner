# %%
import pandas as pd

# %%
df = pd.read_excel("../../datasets/raw/H0001_features.xlsx")

# %%
df
# Out:
#     freq  centro_x  centro_y  raio_medio  raio_std  raio_max  raio_min  \
# 0     31 -0.000452  0.000566    0.003626  0.002853  0.015413  0.000078
# 1     32  0.000232  0.001073    0.003621  0.002736  0.014173  0.000047
# 2     33  0.000242  0.000532    0.003627  0.002882  0.014718  0.000099
# 3     37 -0.000369  0.000496    0.003618  0.002888  0.014303  0.000107
# 4     38  0.000195  0.000635    0.003656  0.002829  0.014686  0.000084
# 5     45 -0.000696  0.000307    0.003605  0.002869  0.014650  0.000182
# 6     50 -0.000188  0.000708    0.003645  0.002825  0.014571  0.000191
# 7     33 -0.000204 -0.000387    0.003077  0.002795  0.020735  0.000011
# 8     34 -0.000762  0.000100    0.003057  0.002745  0.021271  0.000093
# 9     37  0.000204 -0.000733    0.003084  0.002716  0.020590  0.000075
# 10    38 -0.000126  0.000574    0.003076  0.002767  0.020941  0.000164
# 11    40 -0.000374 -0.000557    0.003113  0.002707  0.020537  0.000192
# ...

# %%
df["rqa_trapping_time"].fillna(-1, inplace=True)
df["has_trapping"] = (df["rqa_trapping_time"] != -1).astype(int)
